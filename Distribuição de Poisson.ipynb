# %% [markdown]
# # Importando Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

from scipy.stats import poisson

import warnings
warnings.filterwarnings("ignore")

def drop_reset_index(df):
  df = df.dropna()
  df = df.reset_index(drop=True)
  df.index += 1
  return df

# %% [markdown]
# # Importando DataBase

# %%
df = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/E0.csv")
df = df[['HomeTeam','AwayTeam','FTHG','FTAG']]
df.columns = ['Home','Away','Goals_H','Goals_A']
df = drop_reset_index(df)
display(df)
# Out:
#                Home           Away  Goals_H  Goals_A
# 1    Crystal Palace        Arsenal        0        2
# 2            Fulham      Liverpool        2        2
# 3       Bournemouth    Aston Villa        2        0
# 4             Leeds         Wolves        2        1
# 5         Newcastle  Nott'm Forest        2        0
# ..              ...            ...      ...      ...
# 376         Everton    Bournemouth        1        0
# 377           Leeds      Tottenham        1        4
# 378       Leicester       West Ham        2        1
# 379      Man United         Fulham        2        1
# 380     Southampton      Liverpool        4        4
#
# [380 rows x 4 columns]

# %% [markdown]
# # Distribuição de Poisson

# %%
import plotly.graph_objects as go

pred_goals = [[poisson.pmf(i, df.mean()[j]) for i in range(df['Goals_H'].max()+3)] for j in range(2)]
home_pred = [i*100 for i in pred_goals[0]]
away_pred = [i*100 for i in pred_goals[1]]

goals = ['0','1','2','3','4','5','6','7','8']

fig = go.Figure()
fig.add_trace(go.Histogram(
    x = df['Goals_H'],
    histnorm='percent',
    name='Home',
    marker_color='#FF6F61',
    opacity=0.65
))

fig.add_trace(go.Histogram(
    x = df['Goals_A'],
    histnorm='percent',
    name='Away',
    marker_color='#77DD77',
    opacity=0.65
))

fig.add_trace(go.Scatter(x=goals, y=home_pred,
                         mode='lines+markers',
                         line=dict(color='#FF6F61', width=4, dash='dash'),
                         name='Home Poisson'))

fig.add_trace(go.Scatter(x=goals, y=away_pred,
                         mode='lines+markers',
                         line=dict(color='#77DD77', width=4, dash='dash'),
                         name='Away Poisson'))

fig.update_layout(
    title='Número de Gols por Partida x Distribuição de Poisson (Premier League 2022/23)',
    xaxis_title='Goals',
    yaxis_title='%',
    barmode='group',
    template='plotly_dark',
    title_font_size=24,
    legend=dict(x=0.01, y=0.99)
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Media_Goals_H = df.mean()[0]
Media_Goals_A = df.mean()[1]
print(f"A média de gols do Mandante é {round(Media_Goals_H,2)} e a média de gols do Visitante é {round(Media_Goals_A,2)}.")

Max_Goals_H = df[['Goals_H','Goals_A']].max()[0]
Max_Goals_A = df[['Goals_H','Goals_A']].max()[1]
print(f"O máximo de gols que o mandante marcou foi {Max_Goals_H} e máximo de gols que o Visitante marcou foi {Max_Goals_A}.")
# Out:
# A média de gols do Mandante é 1.63 e a média de gols do Visitante é 1.22.
# O máximo de gols que o mandante marcou foi 9 e máximo de gols que o Visitante marcou foi 6.

# %%
display(
    poisson.pmf(1, df['Goals_H'].mean()),
    poisson.pmf(2, df['Goals_A'].mean())
      )
#Usado para ver a PROBABILIDADE da média de gols do mandante e visitante acontecer...
# Out:
# 0.31884483757910287
# 0.21948823862864814
